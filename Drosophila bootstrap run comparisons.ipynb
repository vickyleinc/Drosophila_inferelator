# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas
from collections import Counter
from pandas import DataFrame

# %%
df_2 = DataFrame.from_csv("/Users/vickyle/Dropbox/Drosophila_Inferelator_Project (1)/inferelator_ng/data/drosophila/2017-11-20_11-30-04/network2.tsv", sep="\t")
df_10 = DataFrame.from_csv("/Users/vickyle/Dropbox/Drosophila_Inferelator_Project (1)/inferelator_ng/data/drosophila/2017-11-20_18-32-01/network10.tsv", sep="\t")

# %%
df_2 = df_2.index
counts = df_2.value_counts()
plt.figure(figsize=(50,100))
df_2x = counts.plot(kind="barh")
df_2x.invert_yaxis()

# %%
df_10 = df_10.index
counts = df_10.value_counts()
plt.figure(figsize=(50,100))
df_10x = counts.plot(kind="barh")
df_10x.invert_yaxis()

# %%
# Out:
#                          target  beta.sign.sum  beta.non.zero  var.exp.median  \
# regulator
# ovo                     CG34355           10.0           10.0        0.960213
# ovo                        bru1           10.0           10.0        0.947014
# ovo                        cona           10.0           10.0        0.919150
# ovo                      RpS10a           10.0           10.0        0.908403
# ovo                     CG14545           10.0           10.0        0.904262
# ovo                     CG32625           10.0           10.0        0.865789
# ovo                        Ant2           10.0           10.0        0.860876
# ovo                     CG12721           10.0           10.0        0.846812
# ovo                       KFase           10.0           10.0        0.863028
# ovo                      RpS19b           10.0           10.0        0.836445
# ovo                     CG14036           10.0           10.0        0.858510
# ...
